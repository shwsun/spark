# %%
# assume that jdk already installed 
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkConf

#conf = SparkConf()  # create the configuration
# conf.set("spark.driver.extraClassPath", "/tf/notebooks/mysql-connector-java-8.0.17.jar")  # set the spark.jars
# conf.set("spark.jars", "/tf/notebooks/mysql-connector-java-8.0.17.jar")  # set the spark.jars

spark = SparkSession.builder.master("local[3]").appName('LocalMode_Hive_Test').getOrCreate()
#spark = SparkSession.builder.config(conf=conf).master("local[3]").appName('LocalMode_Test').getOrCreate()
sc = spark.sparkContext
# Out:
# /usr/local/lib/python3.6/dist-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning

# %%
spark.stop()

# %%
from os.path import abspath

from pyspark.sql import SparkSession
from pyspark.sql import Row

warehouse_location = abspath('/user/hive/warehouse')

# %%
spark = SparkSession \
    .builder.master("local[3]") \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://172.17.0.2:9083") \
    .enableHiveSupport() \
    .getOrCreate()
sc = spark.sparkContext
# spark is an existing SparkSession
    #.config("spark.sql.uris", "thrift://172.17.0.2:9083") \ # 1527
# Out:
# /usr/local/lib/python3.6/dist-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning

# %%
# val jdbcDF = spark.read
#   .format("jdbc")
#   .option("url", "jdbc:hive2://34.223.237.55:10000")
#   .option("dbtable", "students1")
#   .option("user", "hduser")
#   .option("password", "hadoop")
#   //.option("driver", "org.apache.hadoop.hive.jdbc.HiveDriver")
#   .load()

# %%
# jdbc driver 를 spark classpath에 포함시켜야 한다. 
jdbcDF = spark.read\
  .format("jdbc")\
  .option("url", "jdbc:hive2://172.17.0.2:10000/default")\
  .option("dbtable", "t_test")\
  .option("user", "hdoop")\
  .option("password", "1234")\
  .option("driver", "org.apache.hadoop.hive.jdbc.HiveDriver")\
  .load()
#  //.option("driver", "org.apache.hadoop.hive.jdbc.HiveDriver")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-57-5f80584aefef> in <module>
#       5   .option("user", "hdoop")\
#       6   .option("password", "1234")\
# ----> 7   .option("driver", "org.apache.hadoop.hive.jdbc.HiveDriver")\
#       8   .load()
#       9 #  //.option("driver", "org.apache.hadoop.hive.jdbc.HiveDriver")
#
# /usr/local/lib/python3.6/dist-packages/pyspark/sql/readwriter.py in load(self, path, format, schema, **options)
#     162             return self._df(self._jreader.load(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     163         else:
# --> 164             return self._df(self._jreader.load())
#     165
#     166     def json(self, path, schema=None, primitivesAsString=None, prefersDecimal=None,
#
# /usr/local/lib/python3.6/dist-packages/py4j/java_gateway.py in __call__(self, *args)
# ...

# %%
data = [('First', 1), ('Second', 2), ('Third', 3), ('Fourth', 4), ('Fifth', 5)]
df = spark.createDataFrame(data)
df.show()
# Out:
# +------+---+
# |    _1| _2|
# +------+---+
# | First|  1|
# |Second|  2|
# | Third|  3|
# |Fourth|  4|
# | Fifth|  5|
# +------+---+

# %%
df_load = spark.sql('SELECT * FROM default.t_test')
df_load.show()
print(df_load.show())
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     110         try:
# --> 111             return f(*a, **kw)
#     112         except py4j.protocol.Py4JJavaError as e:
#
# /usr/local/lib/python3.6/dist-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o511.sql.
# : org.apache.spark.sql.AnalysisException: org.apache.hadoop.hive.ql.metadata.HiveException: java.lang.RuntimeException: Unable to instantiate org.apache.hadoop.hive.ql.metadata.SessionHiveMetaStoreClient
# ...

# %%
# Queries are expressed in HiveQL
spark.sql("SELECT * FROM src").show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     110         try:
# --> 111             return f(*a, **kw)
#     112         except py4j.protocol.Py4JJavaError as e:
#
# /usr/local/lib/python3.6/dist-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o418.sql.
# : org.apache.spark.sql.AnalysisException: org.apache.hadoop.hive.ql.metadata.HiveException: java.lang.RuntimeException: Unable to instantiate org.apache.hadoop.hive.ql.metadata.SessionHiveMetaStoreClient
# ...

# %%
spark.sql("CREATE TABLE IF NOT EXISTS src (key INT, value STRING) USING hive")
#spark.sql("LOAD DATA LOCAL INPATH 'examples/src/main/resources/kv1.txt' INTO TABLE src")

# Queries are expressed in HiveQL
spark.sql("SELECT * FROM src").show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     110         try:
# --> 111             return f(*a, **kw)
#     112         except py4j.protocol.Py4JJavaError as e:
#
# /usr/local/lib/python3.6/dist-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o172.sql.
# : org.apache.spark.sql.AnalysisException: org.apache.hadoop.hive.ql.metadata.HiveException: java.lang.RuntimeException: Unable to instantiate org.apache.hadoop.hive.ql.metadata.SessionHiveMetaStoreClient
# ...

# %%
Record = Row("key", "value")
recordsDF = spark.createDataFrame([Record(i, "val_" + str(i)) for i in range(1, 101)])
recordsDF.createOrReplaceTempView("records")

# %%
#spark.sql("SELECT * FROM records r JOIN src s ON r.key = s.key").show()
spark.sql("SELECT * FROM records r").show()
# Out:
# +---+------+
# |key| value|
# +---+------+
# |  1| val_1|
# |  2| val_2|
# |  3| val_3|
# |  4| val_4|
# |  5| val_5|
# |  6| val_6|
# |  7| val_7|
# |  8| val_8|
# |  9| val_9|
# | 10|val_10|
# | 11|val_11|
# | 12|val_12|
# | 13|val_13|
# | 14|val_14|
# | 15|val_15|
# | 16|val_16|
# | 17|val_17|
# | 18|val_18|
# | 19|val_19|
# | 20|val_20|
# +---+------+
# only showing top 20 rows

# %%
spark.sql("INSERT INTO src SELECT * FROM records")
spark.sql("SELECT * FROM src").show()
# Out:
# +---+------+
# |key| value|
# +---+------+
# |  1| val_1|
# |  2| val_2|
# |  3| val_3|
# |  4| val_4|
# |  5| val_5|
# |  6| val_6|
# |  7| val_7|
# |  8| val_8|
# |  9| val_9|
# | 10|val_10|
# | 11|val_11|
# | 12|val_12|
# | 13|val_13|
# | 14|val_14|
# | 15|val_15|
# | 16|val_16|
# | 17|val_17|
# | 18|val_18|
# | 19|val_19|
# | 20|val_20|
# +---+------+
# only showing top 20 rows

# %%
#    SparkSession spark=SparkSession.builder().appName("Spark_SQL_5_Save To Hive").enableHiveSupport().getOrCreate();
sc.config().set("spark.sql.warehouse.dir", "/user/hive/warehouse")
sc.config().set("hive.metastore.uris", "thrift://172.17.0.2:9083")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-7af31a7b1b9f> in <module>
#       1 #    SparkSession spark=SparkSession.builder().appName("Spark_SQL_5_Save To Hive").enableHiveSupport().getOrCreate();
# ----> 2 sc.config().set("spark.sql.warehouse.dir", "/user/hive/warehouse")
#       3 sc.config().set("hive.metastore.uris", "thrift://172.17.0.2:9083")
#
# AttributeError: 'SparkContext' object has no attribute 'config'
